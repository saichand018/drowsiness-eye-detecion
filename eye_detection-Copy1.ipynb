# %% [markdown]
# # detecting cotton diseases using cnn

# %%
import numpy as np

# %%
from keras.models import load_model


import cv2
model2 = load_model('eye_detection.h5')

# %%
import sys

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")


img =cv2.imread(r'C:\Users\91918\dataset(eye)\dataset_B_Eye_Images\test\closedRightEyes\closed_eye_1336.jpg_face_2_R.jpg',0)
img=cv2.resize(img,(128,128))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
if (np.max(img)>1):
    img=img/255
        
img=np.array([img])
prediction=model2.predict_classes(img)
#label=['closedLeftEyes','closedRightEyes','openLeftEyes','openRightEyes']
prediction=prediction[0]
#print(prediction)
#l=label[prediction]
print(prediction)

# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2

img = cv2.imread(r'C:\Users\91918\dataset(eye)\dataset_B_Eye_Images\test\closedRightEyes\closed_eye_1336.jpg_face_2_R.jpg',0)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
label=input()
if label=='closedLeftEyes' or label=='closedRightEyes':
    status='closed eyes'
    print(status)
else:
    status='open eyes'
# Out:
# closedLeftEyes
# closed eyes

# %%
import cv2
import sys
import numpy as np

from keras.models import load_model

model2 = load_model('eye_detection.h5')

if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# Loading the cascades
## Loading the Trained Models
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')
#eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_eye.xml')

# Doing some Face Recognition with the webcam
video_capture = cv2.VideoCapture(0)
while True:
    data,frame = video_capture.read()
    eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_eye.xml')
    

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    eyes = eye_cascade.detectMultiScale(gray, 1.1, 4)
    for x,y,w,h in eyes:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255,0, 0), 2)
        eyess=eye_cascade.detectMultiScale(roi_gray)
        if len(eyess)==0:
            print('eyes not detected')
        else:
            for ex,ey,ew,eh in eyess:
                eyes_roi = roi_color[ey: ey+eh, ex:ex + ew]
                
    final_img=cv2.resize(eyes_roi,(128,128))
    final_img=np.expand_dims(final_img,axis=0)
    final_img=final_img/255.0
    prediction=model2.predict_classes(final_img)
    label=['closedLeftEyes','closedRightEyes','openLeftEyes','openRightEyes']
    prediction=prediction[0]
    label=label[prediction]
    #print(repr(str1 and str2))
        
    if label=='closedLeftEyes' or label=='closedRightEyes':
        status='closed eyes'
    else:
        status='open eyes'
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    print(face_cascade.empty())
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    for x,y,w,h in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0,255, 0), 2)
    cv2.putText(frame, status, (10, 30),
				cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        
        
        
        
        
        #font=cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        #cv2.putText(frame,status,(10,30),font,3,(0,0,255), 2)
    cv2.imshow('drowsiness',frame)
               
    
    #cv2.imshow('Video', canvas)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
video_capture.release()
cv2.destroyAllWindows()
# Out:
# eyes not detected
# eyes not detected
# WARNING:tensorflow:From <ipython-input-5-97ffee513f0c>:41: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# False
# False
# False
# False
# eyes not detected
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# eyes not detected
# eyes not detected
# False
# False
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# False
# False
# eyes not detected
# eyes not detected
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# False
# False
# False
# eyes not detected
# False
# eyes not detected
# False
# False
# False
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# eyes not detected
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# False
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# False
# eyes not detected
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# eyes not detected
# eyes not detected
# eyes not detected
# False
# False
# eyes not detected
# False
# False
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# False
# eyes not detected
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# eyes not detected
# False
# False
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False
# eyes not detected
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# eyes not detected
# False
# eyes not detected
# eyes not detected
# eyes not detected
# False
# eyes not detected
# False

# %%
import cv2
video_capture = cv2.VideoCapture(0)
while True:
    data,frame = video_capture.read()
    eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_eye.xml')
    

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    eyes = eye_cascade.detectMultiScale(gray, 1.3, 5)
    for x,y,w,h in eyes:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255,0, 0), 2)
        eyess=eye_cascade.detectMultiScale(roi_gray)
        if len(eyess)==0:
            print('eyes not detected')
        else:
            for (ex,ey,ew,eh) in eyess:
                eyes_roi = roi_color[ey: ey+eh, ex:ex + ew]
                print(eyes_roi)
